# %%
import json
import urllib.request
from urllib.error import URLError, HTTPError

# API Configuration
API_BASE_URL = "http://192.168.1.110:31500"  # Update this to match your Flask server
GET_TASK_ENDPOINT = f"{API_BASE_URL}/api/queue/largest"


def get_largest_task():
    request = urllib.request.Request(GET_TASK_ENDPOINT, method="GET")
    try:
        with urllib.request.urlopen(request, timeout=10) as response:
            status_code = response.getcode()
            body = response.read().decode("utf-8")
            try:
                data = json.loads(body)
            except json.JSONDecodeError:
                data = body
            return status_code, data
    except HTTPError as exc:
        return exc.code, exc.read().decode("utf-8")
    except URLError as exc:
        return None, f"Connection error: {exc}"


if __name__ == "__main__":
    status, payload = get_largest_task()
    print(f"Status: {status}")
    print("Response:")
    print(payload)
# Out:
# Status: 200
# Response:
# {'data': {'before_file_size': 756, 'directory_path': '/boilmedia/Media 1', 'ffmpeg_string': ' -map 0:0 -c:v libsvtav1 -crf 25 -preset 4 -g 240 -pix_fmt yuv420p10le -svtav1-params filmgrain=20:film-grain-denoise=0:tune=0:enable-qm=1:qm-min=0:qm-max=15', 'file_guid': '8f3bde97-5d52-4332-b70f-5da6b343737e', 'input_file_name': 'test_file_01.mp4', 'output_file_name': 'test_file_01.mkv'}, 'success': True}
