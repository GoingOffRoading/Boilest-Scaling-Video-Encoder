# %% [markdown]
# # Checking which Tables Exist

# %%
# Verification: list all tables in the database
import sqlite3
from pathlib import Path

db_path = Path.cwd().parent / 'boilest.db'
conn = sqlite3.connect(db_path)
cur = conn.cursor()
cur.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cur.fetchall()
print('Tables in boilest.db:', tables)
conn.close()
# Out:
# Tables in boilest.db: [('sqlite_sequence',), ('encoded',)]

# %% [markdown]
# # Setting up the Directories Table

# %%
import sqlite3
import uuid
from pathlib import Path

db_path = Path.cwd().parent / 'boilest.db'
conn = sqlite3.connect(db_path)
cur = conn.cursor()

# Check if the 'directories' table exists
cur.execute(
    "SELECT name FROM sqlite_master WHERE type='table' AND name='directories';"
)
exists = cur.fetchone()
if exists:
    print("Table 'directories' already exists.")
else:
    cur.execute("""CREATE TABLE directories (
        guid TEXT PRIMARY KEY,
        path TEXT NOT NULL UNIQUE,
        added_at TEXT NOT NULL DEFAULT CURRENT_TIMESTAMP
    );""")
    conn.commit()
    print("Table 'directories' created.")

conn.close()
# Out:
# Table 'directories' created.

# %%
import sqlite3
import uuid
from pathlib import Path

def add_directory(path):
    db_path = Path.cwd().parent / 'boilest.db'
    conn = sqlite3.connect(db_path)
    cur = conn.cursor()
    try:
        guid = str(uuid.uuid4())
        cur.execute('INSERT INTO directories (guid, path) VALUES (?, ?)', (guid, path))
        conn.commit()
        print('Inserted:', path, 'with guid:', guid)
    except sqlite3.IntegrityError:
        print('Path already exists:', path)
    finally:
        conn.close()

# Example usage: replace with the path you want to add
add_directory('/media')
# Out:
# Inserted: /media with guid: 44fb6f99-dd47-434e-9b3a-5e44c3f1fc48

# %% [markdown]
# # Adding rows to directories

# %%
import sqlite3
import uuid
from pathlib import Path

def add_directory_path(path):
    """Add a directory path to the directories table"""
    db_path = Path.cwd().parent / 'boilest.db'
    conn = sqlite3.connect(db_path)
    cur = conn.cursor()
    try:
        guid = str(uuid.uuid4())
        cur.execute('INSERT INTO directories (guid, path) VALUES (?, ?)', (guid, path))
        conn.commit()
        print(f'Inserted: {path} with guid: {guid}')
    except sqlite3.IntegrityError:
        print(f'Path already exists: {path}')
    finally:
        conn.close()

# Add /media directory
add_directory_path('/media')
# Out:
# Path already exists: /media

# %% [markdown]
# # Adding the Files Table

# %%
import sqlite3
import uuid
from datetime import datetime
from pathlib import Path

def create_files_table():
    db_path = Path.cwd().parent / 'boilest.db'
    conn = sqlite3.connect(db_path)
    cur = conn.cursor()
    
    # Check if the 'files' table exists
    cur.execute(
        "SELECT name FROM sqlite_master WHERE type='table' AND name='files';"
    )
    exists = cur.fetchone()
    
    if exists:
        print("Table 'files' already exists.")
    else:
        cur.execute("""CREATE TABLE files (
            guid TEXT PRIMARY KEY,
            directory_guid TEXT NOT NULL,
            file_path TEXT NOT NULL,
            file_name TEXT NOT NULL,
            date_added TEXT NOT NULL DEFAULT CURRENT_TIMESTAMP,
            FOREIGN KEY (directory_guid) REFERENCES directories(guid)
        );""")
        conn.commit()
        print("Table 'files' created.")
    
    conn.close()

# Create the files table
create_files_table()
# Out:
# Table 'files' created.

# %% [markdown]
# # Adding the Encode Table

# %%
import sqlite3
import uuid
from pathlib import Path

def create_encode_table():
    db_path = Path.cwd().parent / 'boilest.db'
    conn = sqlite3.connect(db_path)
    cur = conn.cursor()
    
    # Check if the 'encode' table exists
    cur.execute(
        "SELECT name FROM sqlite_master WHERE type='table' AND name='encode';"
    )
    exists = cur.fetchone()
    
    if exists:
        print("Table 'encode' already exists.")
    else:
        cur.execute("""CREATE TABLE encode (
            guid TEXT PRIMARY KEY,
            decision TEXT NOT NULL,
            ffmpeg_string TEXT NOT NULL,
            before_file_size INTEGER NOT NULL,
            date_added TEXT NOT NULL DEFAULT CURRENT_TIMESTAMP
        );""")
        conn.commit()
        print("Table 'encode' created.")
    
    conn.close()

# Create the encode table
create_encode_table()
# Out:
# Table 'encode' created.

# %% [markdown]
# # Adding the Encoded Table

# %%
import sqlite3
import uuid
from pathlib import Path

def create_encoded_table():
    db_path = Path.cwd().parent / 'boilest.db'
    conn = sqlite3.connect(db_path)
    cur = conn.cursor()
    
    # Check if the 'encoded' table exists
    cur.execute(
        "SELECT name FROM sqlite_master WHERE type='table' AND name='encoded';"
    )
    exists = cur.fetchone()
    
    if exists:
        print("Table 'encoded' already exists.")
    else:
        cur.execute("""CREATE TABLE encoded (
            guid TEXT PRIMARY KEY,
            after_file_size INTEGER NOT NULL,
            date_added TEXT NOT NULL DEFAULT CURRENT_TIMESTAMP
        );""")
        conn.commit()
        print("Table 'encoded' created.")
    
    conn.close()

# Create the encoded table
create_encoded_table()
# Out:
# Table 'encoded' already exists.

# %% [markdown]
# # Adding the Error Table

# %%
import sqlite3
import uuid
from pathlib import Path

def create_error_table():
    db_path = Path.cwd().parent / 'boilest.db'
    conn = sqlite3.connect(db_path)
    cur = conn.cursor()
    
    # Check if the 'error' table exists
    cur.execute(
        "SELECT name FROM sqlite_master WHERE type='table' AND name='error';"
    )
    exists = cur.fetchone()
    
    if exists:
        print("Table 'error' already exists.")
    else:
        cur.execute("""CREATE TABLE error (
            guid TEXT PRIMARY KEY,
            reason TEXT NOT NULL,
            additional_detail TEXT,
            date_added TEXT NOT NULL DEFAULT CURRENT_TIMESTAMP
        );""")
        conn.commit()
        print("Table 'error' created.")
    
    conn.close()

# Create the error table
create_error_table()
# Out:
# Table 'error' already exists.

# %% [markdown]
# # Adding the ffmpeg settings table
